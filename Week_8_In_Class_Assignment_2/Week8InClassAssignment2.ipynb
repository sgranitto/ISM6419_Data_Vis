# %%
path_to_zip_file = "datasets.zip"
directory_to_extract_to = ""
import zipfile
zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
zip_ref.extractall(directory_to_extract_to)
zip_ref.close()

# %%
import pandas as pd
Location = "datasets/time_series_covid19_deaths_global.csv"
df = pd.read_csv(Location)

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/23/20  3/24/20  3/25/20  3/26/20  \
# 0        0        0        0  ...        1        1        2        4
# 1        0        0        0  ...        4        5        5        6
# 2        0        0        0  ...       17       19       21       25
# 3        0        0        0  ...        1        1        1        3
# 4        0        0        0  ...        0        0        0        0
#
#    3/27/20  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20
# ...

# %%
# %matplotlib inline
import pandas as pd
Location = "datasets/time_series_covid19_deaths_global.csv"
df = pd.read_csv(Location)
plt.plot(x, '4/1/2020')

# set the x and y axis range
plt.ylim(0, 1000000)
plt.axis('tight')

#add title
plt.title('COVID-19 Confirmed and Deaths')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1014e444074a> in <module>
#       2 Location = "datasets/time_series_covid19_deaths_global.csv"
#       3 df = pd.read_csv(Location)
# ----> 4 plt.plot(x, '4/1/2020')
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       6 # set the x and y axis range
#
# NameError: name 'plt' is not defined
